# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias


def lossFun(inputs, targets, hprev):
    """
        inputs,targets are both list of integers.
        hprev is Hx1 array of initial hidden state
        returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    
    # forward pass
    for t in xrange(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(xrange(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []

    for t in xrange(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
# prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

# sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print '----\n %s \n----' % (txt, )

    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0: print 'iter %d, loss: %f' % (n, smooth_loss) # print progress
  
    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# data has 1115394 characters, 65 unique.
# ----
#  G!o;d$:hH'Xx:sjDZBAEuHqOTEQqqnHvH:FYBgJof-Q UHsZsP'wNIYZyElIb-.3L:x!,HDIw;kaSaIfqqeRiK-VGrEp&Q',eZ:veL3peiBbIbAjR,.A
# mmoyt$L
# pM3uxTGZy:A-KrVfHAy;BXh!O.UcielRDbqIIeJTf&uhPr?'T:&PL,YQvnYVPhLB'jml! l$z!m
# ----
# iter 0, loss: 104.359684
# ----
#  sgoh hht
# an:hnthe isenhd
# arhointkVthssiatd lstssty
# ms t nhso elrnrs lhdtnnsw
# skkeCn
# no eth pae s i
# dhesirseuyhohehanhe
#  nprnef npgyheesoy s;oh  oan te?pr:tf  esth lotpsi thsssuh eh,halMs e at tshs:r
# ----
# iter 100, loss: 103.819130
# ----
#  cwreeleh euel ia
# l n
# ylyneuckn hhi shTluto,lnThosnhe ysn iyigsoFnee uiamoan,e!enl
# Niuli
# tnrshriceolnayTbebcoeo,hvrnlelnearoenafninn
# TCnseskntehenvdU
# i ulan eTen dTyo ieyba  aeduaancootdleoieN l;eciTni
# ----
# iter 200, loss: 102.047666
# ----
#  au t sohuCHvc
# Heuvets
# :otiuCH alrsroba MFC?
# b n
# d ues
# Fsdrewelso d hofrnUovwi
# sn
# nlg YveH  g:ilyauHli vHts iItheIeewwvo to
#
# al
#
# Hr r
# F:,eweilr:itigmot d
# H'd
# Hi,
# H;uR
# S y ?
# ghe Ibe
# h dwl, dis
# vi c
# ----
# iter 300, loss: 100.289869
# ----
#  rdro we:f c
# trosn,e iif
# shuttswVsAe beir ortu ital
# l:,rpswE idr tis otiASos to
#
# Smth tith v tyu,n dee :iter tsS
# FdE no,eostdht
# aocnsod .noE p S,ctdro eehhrr.-' kotowd toteethucmrerd twnr yo, ,rduAdu t
# ----
# iter 400, loss: 98.168296
# ----
#   thiphog Oose sUiOer iUee,s arsnoofrschathhbo nns,e:esa'R'rs ssn'o cirde sybes Su eut thssa
# soieiOilf g isrdis gn tUeths nee'Ill heio
# Fhe ebisi tsemnsin se
# n he ioieucoEilddos beU:
# gn hio sgf bnheiusO
# ----
# iter 500, loss: 96.295590
# ----
#  unonadnet dhmon weemnaUAio ohe, chuyhatoon theps iethe; the
# ahaeotn tony
# yhtf wousm'doue hur dhe plhk cee
# aanhe het asm.
# io shils'ttt mha
# Meweenee ame neF  t aent rpy  we allehe morekesh cocafl lw eas
# ----
# iter 600, loss: 94.045729
# ----
#   yod cadtdoy:.
# te: enchi gogfeoe had agt hes hasy lulsnf ;aang arineu net ant eoutand; Lutahe naditi, angk orltyUV gid Hageed we.
# ne loeaysah as nodayedgorhreegaeaemthee nalaaintoiagetiaere  and n iaa
# ----
# iter 700, loss: 91.992789
# ----
#   tor
# MUMCRIE
# MFrg ueeR caaS
#
# FELIL:
# Cevet.
# TU:
# IU:
# TN:
# MScy Con woan Moce
#
# S:
# Th
# S:
# TiLe,t lCRye.
# TRGILA:
# :
# Thbwicf,dlyen,
#
# GS:
# AS
#
# SoyL yedy:
# ?URU:Tt
# SI
# CNEIALSERI:RkLt, maatoua to mog ve dUlUAU:LRFI
# ----
# iter 800, loss: 89.546052
# ----
#   yatsos Ss wbnuppsanlsithe wt les sit ppostiurshifus van thoavtss motsif.
# Nheud Con c:tusw
# woms fhek stvehwss tons s.nf.
# Ler, wit wo wg te sAalw ys
# Rid b'.
# Whl.
# TAs vn s lawat thewn ssdens wsly'ls, ;h
# ----
# iter 900, loss: 87.379693
# ----
#  wire:aot
# wuos ior
# hund erss hork
# Thin:
# yge lit, sigoe, te:':
# Ohem:
#
# 'UUS
# NN
# RIUS
# Oh fotr oset dfliry borre.
# MLitin; dirk
# iure mond tot wond ont
# Tivder courus yound fokir hmir thee herd wovanr; art to
# ----
# iter 1000, loss: 85.405892
# ----
#  Tegliuchis nayCt igt hesgl-- touuses, fonu sule wigas thele manan Wovyon.
# Tithe, trded thel,
# Che Anv indes: aherd gound
# whotrtnan dit tht are cisthu t!
# Thy etrib bon woe
# F
# TIne ca lons,
# Tha the to enn
# ----
# iter 1100, loss: 83.221490
# ----
#  thot, thie
# Art Iyma: yoed yon the drtheth ear:
#
# IOw, chesede;
# Yf;
# y:
# MtU
# OsUS:
# Whe, g ml tons sao, wheot:
# S:Choc; hasl as, thrt thone, rsotss pw Whe las iut  ba dor:
# HeI
# I
# ACCIARCIUS:
#
# A RRithe thar o
# ----
# iter 1200, loss: 81.300963
# ----
#  lorr goun g t Nanlh mhanher alc salp thes b.
# Inott aleat vis ;:
# Spt op fals , mamau I au yikalt pas; twolg,
# Wh: he hahe, ul hisp mhobl, ovl sh sud le thite nle g m whi aceildavy bon ce a altls, Cy whe
# ----
# iter 1300, loss: 79.598215
# ----
#  oums cLWor foi dthor sor:
# Hot eme honthyld Iot Nerl my heveiarss thery iroth ditad yould 'heegy.
# Wt au gesem ord accau tiresl butary t heuy be gony thinf weme sat sirn:
# My If she,
# Whe ssvet Aat moed p
# ----
# iter 1400, loss: 78.124599
# ----
#  y uabed yhing ined maos yaravk thes yous bumhy lp.ame toues tomcho, toulahylady
# if matatd ale asl aney,,
# Ielapni The t or anpas, camy-le seufy;
# fholt
# y
# mauwy-ll numangitias thetiugg uegtshi
# Thank biva
# ----
# iter 1500, loss: 76.463701
# ----
#  he.
# It the eau aneeo; Mfrif
# Mor
#
# CLOI Ieagoth  tnh;, aghe, anm Iumle afes ranp
#
# MARUOUS:
# Tlarhes mimcuve ther, hemerikmitiug' tose porn rusarn.
# Gt theas:
#
# Mn:
# ans the or, soathr?
# Wpoun: af aodan toud
# ----
# iter 1600, loss: 75.154553
# ----
#  mhenetoo
#
# ome thawerheegat; Imwuri.
# yord anltroenwWoushanl,
# a
# ilwe be ailave loves yoosoun antol! WiOl;
#
# Mndian.
#  be:
# Louus ay hime won ott'rwinmen.
#
# Mridiseougers,
# Weoodsacfith aMT be dhe
# youkoenare
# ----
# iter 1700, loss: 73.733559
# ----
#  meilrews
# theut femgamene pom yous setipase senpi't ru tharp
# 'eranderes
#
# Drlof anren
#  efantet.
# He pows bilsae wopthye thouglacsucks .yiwrrsuerg egrele gi anp ind
# loreirefgin wotnwereo elinp'f
# Werganl s
# ----
# iter 1800, loss: 72.625707
# ----
#  'g sifen theoshes yoan erure tol cabreatoratcon,
# Bure h iiplor
# woch,tois: an y andf hhacafres wouveef:
# oacherd 'avf on!.
# Wnde foreo rfor nce woud hof cancsp'rnyvoud thetpe!
# Hace 'ou, ctotce.
# Toubtlwes
# ----
# iter 1900, loss: 71.271119
# ----
#  arlo'd
# thaceas.
#
# vOLIN CILININIUS:
# Wearss
# Houpsd sherpndtr y and,
# oe thesitos hevear haphet.
# AfUS:
# Whe lu
# deatthar tour the ongerst afut bas I
# Thet as ae thy
# Wero heatne, eajoif redeweedotses
#
# CheTI i
# ----
# iter 2000, loss: 70.143772
# ----
#  mcene mick, oo Onee kith thoad foot oel mfond efkeve y ientleele marettn, ith theis flisiclme dathenod oncaxci omy: beqkcypbulnifton'e mis
#
# ARNo EsR afid
# Aatanct of man; cils
# 'f
# Ionpr my coDn whepered
# ----
# iter 2100, loss: 69.233733
# ----
#  r: Couwe hre fers woudte ou too, mu ethe fou! noulepucirurt th meos oor ho ouis the yyooupusa to hopsgts, wes si fo awi rald hecve ousre toule cad ttilwor.
# Mhit novet berpod the rore mun! so ho koons
#
# ----
# iter 2200, loss: 68.076044
# ----
#   i mrevinive ho's ay !
# An yuve lem mo youl.
#
# SI Ist tit
#
# S: I' the goes sr mle hand, mom it you contd yould fle: tolf mave momir'tsv mplom lo'g?'g
# ange ss wame de fun.
# Wy yous uoth chav
# kuv, chiur mul
# ----
# iter 2300, loss: 67.309880
# ----
#  nlive tou row rinl to comengt ace thes,
#
# RCOvesmove aeke hit C weve thicecs tvat, hoar: youthuge dey tho
# Aoud docet opko do s iur mewtit dourc ik ve the so , anze to glans, dovdevy cid an ysu gorl wor
# ----
# iter 2400, loss: 66.234810
# ----
#  Chacs'd,
# Honize hell'd cr wou,ts,
# Toolld of  hom; mar at sain mek the ham war is o'ld.
# Bnoug,
# Bwrind Houd: Kud, nu y, soank, uot,
# Heche
#
# S:Al noses
# are shesldongen:
# 'nver wot.
# Citizw ind me as she lo
# ----
# iter 2500, loss: 65.296764
# ----
#  o he
# bems'r' palidt?
# Ard he thir thout buslours
# Tpyperk thett theied tampriuguuncass your tos
# Yicns coutee nnhenese'lgszesrres som;
# Houcerevcictey arou sizvegedrf hemer,
# To wo, jot o hy.
#
# urd ne phici
# ----
# iter 2600, loss: 64.531963
# ----
#  ou.
#
# ARALANUS:
# diOfosd warlt
# And huort eof that nott saked the anttugge fold, sir Youm,
# Thatd ha, he wo chh kor.
# Awaver, yore geurd licpat hiweild thet uut dores: the pricoorste,
# Oukte, onl-
#
# BRARIICR
# ----
# iter 2700, loss: 63.784797
# ----
#  e,
# No the.
#
# Fisic. woud wim, ar -ridy som hy, the Cpicl, tittnpre to nore nous shaves to aoo,ein wins y sis hela as, tienpael vnir thars,
# Now;
# The
# To sey thins  we dom wprit
# A yot,
# Nofis sraf
# CIUS:
# No
# ----
# iter 2800, loss: 62.692305
# ----
#  etslelgind
# drthart
# Tod,.
#
# SIOLANUS:
# Toore o hommr-nthay mati Yos, wipowon.
#
# COIIINININIUS:
# Wase bos hese and lesw.
#
# Fitttano cottounggoriss asr coen'eree,
# Lethabl, hat wane't thed cret themee ho't, th
# ----
# iter 2900, loss: 62.150362
# ----
#   baal yot weite pe theoct swete me m
# Het the by thege thod, aamlr witt,
# I Do thpule Ruutlon thelby wile ereun besl hebe re ceit wind idp,, ;ree onr 'he he arl sapy soer mish mat ditd that furt lits so
# ----
# iter 3000, loss: 61.606566
# ----
#  ibe we cild.
#
# BENENIUS:
# IUS:
# SIOm,
#
# COCINIIINIUS:
# LICiMize puvure fhaplith the!
# Whete' youn theceo songand yous, youlas thet ruxiple pible ond tover foep enop yous if yom ghees: dhe mere bether to ero
# ----
# iter 3100, loss: 60.961215
# ----
#  y mangnet,
# Souserays! bule , Anory thas uull terts
# As fias: hillgme cor sorghuth mull flath
# f
# And the hat, thest nours: feasl!
#
# BESIAstes as lopleterp-S
#
# RETUS:
# Wey pou he the's he 'outouq-
# -us.
# Maro
# ----
# iter 3200, loss: 60.300598
# ----
#   de'e pulsse domd hit thont mim ore, of it weras bot! -ant I'lind mare Funey more.
# Beed; Sero ond I endinsmPn then.
# Whote wile bile havid
# Wiblen br thes
# I bot hest yousst tabr, beonqurs, a'd-angagont
# ----
# iter 3300, loss: 59.835425
# ----
#  t ilicehe''g nhoted thot yocfore eron the hat I hivy.
# I Asd u hhat toe, bf it,
# MEApo hersond no yor
# Ar ansthe
# Wey bat.
#
# SENENIUS:
# Out oungang rit dtnt'e, frein the gere fot anstr,
# Bothal
#
# feches ronor
# ----
# iter 3400, loss: 59.168634
# ----
#  AnN lat, treth,
# Gore burys buale
#
# BLALNIUL:
# Lllg whare buing ffsriingi ires
# I
# OIOLNIUS:
# Se
# A'd to Cefers
# Aw re
# Thit, proth ir thathele d be thind; iuggse be was theldi rist clan,
# Cift thale
# Theye:
#
# MA
# ----
# iter 3500, loss: 58.675229
# ----
#  od myiap gels couttaof
# Cathacs be wiile nour. weitheagdee behaln miy ent deand ower wo theit luly uyustilsimle baveay bandtoniwred?
# Apnhe cered:
# Toos pot lond wirpreicess
# Livlars ineces am noct nobt t
# ----
# iter 3600, loss: 58.426078
# ----
#  NUS:
# Cizint doss le cit hliktaeg ticon,
# Ay. fishyil- s ws ve mpes, apal the hill kongu d arn, trece dassibyeser pathale po wis' cimisf fof beuips wo, tous, caccareit lear s alll,
# Wik tice,
# As itk ules
# ----
# iter 3700, loss: 57.972214
# ----
#   soecd,
# Hay sandonsem':
# AnlL, be
# Thallime aror!
# Rourg ind hew lyathe chibe of and!
#
# MENENIINUS:
# IIAI b
#  nnruses bp ay.-
# Mwietie daon in mes'g,
#
# COCINIOLUM:
# IUS:
# you do, breld of po'r yo anle if whe ci
# ----
# iter 3800, loss: 57.533144
# ----
#  y shun, nltesey,
# Whaerese ditoni, I to bemour.
# Cievel yoserely
# Be peare, meme ourte heae, soreoussn,
# Sese peakew! the thenst ans, cny whes gxien:
# He n.is, mennss, eont
# Weis manf anle pwat ast yout
# Bea
# ----
# iter 3900, loss: 57.414663
# ----
#  tiy.
#
# CORIOLUNUS:
# Whrirtc sorer, foak br ho mo che stoy, t
# Ast? uns, sho gon bitoll gore the notaablc he sepef land mace old us ere, saaUn os have whyag shas he ben!
# And heake
# Ad whaz my chaind hof ho
# ----
# iter 4000, loss: 56.971949
# ----
#  e oftt ip Iist ins wavang the and domire ball fite tall han and eektarf bnstus thou adt in, sat af wo hoats? in: you the:
# Andise any at pitin tiRin I pomarws bimomc' ain: bat 'alc ho'ge. yob-ert IOang
# ----
# iter 4100, loss: 56.634007
# ----
#  ewak hnome;
# And moun ins heme ssud thit of heen:
# I bowum lreir;
# Ronsces, stathan
# I lisad spore iplprucn cinnsecf auime,
# Thade youss pot weparn thas, heor siw nark! Meow the to whenrs nerns. Infert, go
# ----
# iter 4200, loss: 56.556185
# ----
#  r
# Dteun:
# Ir the forvan:
# 'nd on math unee mure, nace'tA thin: I to ; isg fgongit'd fraw theme, muths , thu ys.
#
# COIUStUS:
# Tny , the prou m've;
# --:
# doe catits, ing,? oot snotvess? 'es ove got Le palll?
#
# ----
# iter 4300, loss: 56.109777
# ----
#  irc f'erise, is bitiond spry hinen you iech hers
# Ont thin; I butind hnobe argid thee hos mr cxty mlld; hoon wat And ave ksram
# Thy thive
# Sorr I van sise harncemarg ibid of to o' on mive
# I gous hent,
# Th
# ----
# iter 4400, loss: 56.018506
# ----
#  t and bin cotd I mekst,
# LindrIe fnome humly.
#
# SlrIUS:
# Whan: mevome't he loriFlome sare you spre; be hemf
# Afrive thy home
# Gerice heas thes
# Mord mick, anringt sans sir: lare obrr-Rour Mhe our the tor
#
# S
# ----
# iter 4500, loss: 56.015467
# ----
#  gstly hay:
# oree himed
# siid 'ly he
# dround. ug!' yor now an:
#
# hit, wi fo bitelre'ngan:
# Oim hithvit harce Sar pimirl ex is tay, han:
# Fir kourit serkurwer mave, angir tar mirsernFor to ser nod; be to ave
# ----
# iter 4600, loss: 55.859971
# ----
#  s out gone sarku hilg ary.
#
# SICheino, holghersiuv hengioncery to hi go, you the poce nevirsale hand
# utgnle he
# S.
#
# SICINIUS:
# Sant in iest
# Wonso'd
# -lithingesolsais -oul fit,
# Say telq, csinct, ly avem;-i
# ----
# iter 4700, loss: 55.713376
# ----
#  ttour-erdsm:
# Whives your out, unes reared;
# She heanfen or
# IGiryoanere bame, ins nowervin,-anres wopee 'owss saind Ind, ofh'ms?
#
# MRMIUS:
# Tor' thal than:
# Thut his hin thes?
#
# COMINIUS,
# LTwomer?
#
# MENENIUA
# ----
# iter 4800, loss: 55.509242
# ----
#  nsu thes vein:
# As enthan hom thon
# Alei, ae tacu pnillsome fathe find home ole ho, fateend
# A cor fropd cheintouseur not peace, vishien, in un;:
# Memesce umann: Aun.
#
# BMiz, nowiJe dime.
# Yous of asiof?
# Wh
# ----
# iter 4900, loss: 55.424744
# ----
#  en rid, she kpryle, ay uf le eove ho: to somes wall hke wily in enTrrtuy ysu cos ont hit bid; inle, of Roble outt . Re cith tazelele.
# Bltnst a bove he vageg: eosee,
# Y loat wimlkescoe gise net fino fa
# ----
# iter 5000, loss: 55.283483
# ----
#  ot rene sle; tese af ill satese, jof you he cot ke
# Whele, the heem, yor
# Of henan:
# he:
# Mhe traid the spopy
# by sers tor, pfaretensee's ane you it
# Col hor, Cortre yourt: huolt
# So the sarde,
# He the pcour;
# ----
# iter 5100, loss: 55.215748
# ----
#  our oR
# oop and he ky dour sbrendae, Mroune:
# The, I part hon,, aft oftin, havene, but fot to noses erever co tibe,, wir; muthr befvecss feak heak ketrfave ourd
# Yourd andilge: fasings,
# SHe noRst fo ors
# ----
# iter 5200, loss: 54.966983
# ----
#  t be knos men no hopd sarome
# Yourpofrinf now is to in werth bassmoset', Whigsst end lonn,,
# Ds hayf nenr,
# Raich nrllir ant nofort be an holy, healg nopure the famy wes A, thaf namy wingaik,
# Nofie our g
# ----
# iter 5300, loss: 54.900149
# ----
#  se.
#
# Mithenstes,
# Whaveraod chanad chos hewy strllor Re ant!
# Whecmert!
# Yogi-thavitang lowy!
# Camvad, andoges thace onl he cithey, way, you, yonngenesercas:
#
# brorl of bres malcted o h caothy
# Andant
# at
# So
# ----
# iter 5400, loss: 54.848619
# ----
#  I
# L:
# I NIUS:
# AThas hist yotis, wheta gpot snow nomlor baR
# Of,
# Dat oulp.
#
# MENEUThe
# This in hore, mu fuesces, prom, ou plithm
# AT
# Prit by
# And sty!-Me Rear bot'se fnowf of hall to sf mane Iulens puipr, of
# ----
# iter 5500, loss: 54.991751
# ----
#  li hame wor se po hant tat 'st pot ber stonerelt'r,
# Thoussy, stooe
# Whingr, seersto ance for'le foly be arenge bese the of heans birkd, dor hen stlincu noo rart of tor how sone, Pro,e thow to honden ag
# ----
# iter 5600, loss: 54.877007
# ----
#   had tangonthourys whepishinns olns, thou.
# Thu acd in you ur porl snose cetest
# Thes as how our hikpow,
# Andianpe's u.
# Thou to ale s'le dollier. ath hidb pupindem: Tolnius nefop qurianst to thasspTfon p
# ----
# iter 5700, loss: 54.898271
# ----
#  tad beat was that wite peot and an'e whipl. His wige thon drand-iath potrat reRsagangaldouransangeerseris nnrtice. he hyrang, Hic, agaths Oried hanusteiggelu
# olisig; ane! sor feot weas sseis ma ander
# ----
# iter 5800, loss: 54.814253
# ----
#  ed hates cellierpto his wave tane falcachy hom. iM hily
# Prirse doot raod hall pedren:
# Andsre teonlt of makperu
# yome 's my thay nfome on thau'd o leccond,
# Werhet.
#
# SICINIUS:
# Gey and thlu
# Sere lear thop
# ----
# iter 5900, loss: 54.742379
# ----
#  s fod aulis.
#
# rlist Moll hiech
# Alcil with to to kesurr, inthon: Cith shid how'd hives thed Of ape best neerert, d wheer he thicy
# He thar hay lasp eeeuee, nore,
# Whats ho thipe toate
# now boir alligetp n
# ----
# iter 6000, loss: 54.724797
# ----
#  heecdncy tow ve of to highe tore:
# Tor igs
# Thau the mur?
#
# BOUsicp you, he
# Anif ou mave hour kerly per lo he th the coy now leime
# I gy wo yaes!
# ale pfallir iite touss enges! Sir mige':
# Gour.
# Hi tade, w
# ----
# iter 6100, loss: 54.536810
# ----
#   thethsmag.
#
# Fhistd loas pede do; id hery
# starn thaLs fratmout alsald.
#
# Erist.
# Fyour go he har Me'trles flakes wiras'd swabigust Irais furn:
# He thoufo wath d
# Glllinns lpRelm buerul
# Aud, bo das jnat gl
# ----
# iter 6200, loss: 54.749628
# ----
#  , wit sfert usteds
# Heoied, trat word;
# Hat lont, Thard Vraingn pefily, herest
# And,
# Wyow yous wiindse the cot fhatecerler of der?
#
# SIUTUS:
# I dein drowen,
# Het;
# Thar to thase.
# AGRond pold wrend? Ther shat
# ----
# iter 6300, loss: 55.151533
# ----
#  and the morsorur rare the lanpllh shurar hat thim mumcuud shist cows on prot Goll trat cis ofe the wernt.
# Bat sow,. Fall enst to ont
# I ont.
#
# GOFRGReold with your, pencey
# Go the chale thee he thy the a
# ----
# iter 6400, loss: 55.404519
# ----
#  her hiid end acos kwes as om't veredd both I dikid at wheel then gfpapes, my dive fhet yo thacn the, Pall, my ther that trou!
# :
# Wind I 'd and nocs?
# The dand wrre, hor
# The, the to I wemand.
# Hand
# Tor th
# ----
# iter 6500, loss: 55.452706
# ----
#  nes feacss! fr this y ully toudowt! pore it talls theneld Coren ind thush
# ERin thon urpence budit tousfur dist un os,! vo sheanfw marcie and, byom whoust cat kaLin for wrOx'd she,
# so the cor thanfnt s
# ----
# iter 6600, loss: 55.520844
# ----
#  ace
# Not flrend,- onist now the aur thes pet fhouly not hat gothe antteng, mreeckoue thoun thy to carnouf!
# The weat, dimee mole thiuganlthak kolT poate wannsurtert,
# And mwan chall putus; let ptiple dou
# ----
# iter 6700, loss: 55.122836
# ----
#  ttand ornscnyet ond greomay heonds.
# Thit vy hexth the os thesay efenger non!:
# The put dlenctorer wers mad hin pulf thar drathangd;
# Thath Moun urpengustempfting,
# Aficest my, be elat man fonn!
# Thoupy yo
# ----
# iter 6800, loss: 54.633655
# ----
#  rrars and I kery trye'nd thes and abnt diftate thor whouser sorrll.
#
# AEDY Alo an wealgt; he haver.
#
# LIDLAst Whanly mor srimt arit liren andire get dakisponth, hoth or out.
# Whris, in ther hin harr, I I
# ----
# iter 6900, loss: 54.128318
# ----
#  d. I Eglngade? By wigh anke gows oln koullid, restores: Vo cusmeverpy,
# Why.
# He ecedy jy nomed as the yougessed and be be tho,
# Ivecar hit nevion one, we chised ambthceny,
# The sot to feed sus.
#
# GGOERNNE
# ----
# iter 7000, loss: 54.512587
# ----
#  AUA:
# Hond
# iutarks with yous, atall klederere dicen erat ne, peane,
# BrmAmever Mn aed-erome sstpare by to hop:
# Mingerctake fnoneded ney, Jave AmHe.
# Heer wesend youulfo, bis feanch thowe?
# He cangeftlat t
# ----
# iter 7100, loss: 54.608805
# ----
#  to int wiet tot'd.
#
# QUS:
# Oy If ipfruss oncusespy not be as aided hence-
# More, suisenl.
#
# QCOUVES:
# Roly theullysibu' my?
#
# GLEREAER:
# No pame one preach I mestnersu?
#
# ALANRA
# GGRI I EGANES:
# I kan ayke by h
# ----
# iter 7200, loss: 54.565379
# ----
#  , mave Awath sre-n
# GGoI -por tare sowtttas noble, mamses face heul cteus 'le of ine, hu the dighre rapongacitd
# Ale bured bustheere, to ches not mint oud thee the dable ul hapnyoue Es the tres ly asd b
# ----
# iter 7300, loss: 54.381297
# ----
#  watid they ce!
# Whetd-
# : brerts!
#
# QUEEN:
# He laty hathor, I hyorial youry, I lapellor, thar whecss.
# Gnoof Hamy'ds thact for thatl vinle.
#
# QUEENE:
# The coo cours'. Pof follt botedo'd the.
#
# LOLCERGARGAN:
# R
# ----
# iter 7400, loss: 54.304124
# ----
#  ge dolyserusce, thet. Ray for yourld the neame lly ard'y arded fhoweveed, cimy!
#
# VUOUCANTed a lepetheastous ateare out thye-starte teoure,
# Ande bey;
# Sfavoace, you mall bis syoo, thes shath the full-
# W
# ----
# iter 7500, loss: 54.120086
# ----
#  VOUCEREATlR:
# I pron,
# Ade,
# I worg my evecvath hin whe, your modcury. uwing, and Vo wank.
#
# GECERTOFA go lewrid sur bowe!
# I to has inge, mmsen! for they
# But iu. uowhed dot icot whies, dond, thatherd sor
# ----
# iter 7600, loss: 53.918887
# ----
#  aroy, seat inderd,
# And?
# inthat topentsouch! I his thad
# To wlots wahe be if iven math lingty to fand soPrt sor to marks.
#
# SHRENERGINER:
# Rint noy Bnty yit sil hoo sace as whes sin tten bigh,
# That buib h
# ----
# iter 7700, loss: 54.094529
# ----
#  BREKENBo kory:
# That the dyee's so daul conre dingeronerse sele himeidink ?igent dether to cothas I wips hist'?
# Mfloset,oes wrathined herel whe toll foml:
# I, in?
#
# CERGERERICATEK:
# But anltas nour Your,
#
# ----
# iter 7800, loss: 54.206217
# ----
#  t wey loge the reat as mont'd in dev he, to teous fut miek.
#
# Thed my there en.est the tith 't cond.
#
# erll and by theas of muw kivm's on by ryibe mooc we fol:
# Nor thaunld e? him noeit. wain ceut le? I
# ----
# iter 7900, loss: 53.970560
# ----
#  EN:
# You.
#
# FLCCENTo:
# Tor uf bithan shat wosher thy wront ca to huwts to ceUS:
# I hat, and of shingare dost surd.
#
# MARY:
# I dane as houd shage goored choursee'st beall thou conthtn'-:
# Thas the sar'd Meert
# ----
# iter 8000, loss: 53.639890
# ----
#  ealll futar worlee pean, of, fur for averbie vereccren to noob that on you simy hivis.
#
# ALARENENCCNoblery, you naind,
# In, lersings werend tould
# dedcoog
# As sur, dor eids, Ed shagcrtland filly out or lu
# ----
# iter 8100, loss: 53.194208
# ----
#   bill supris he sfimmaeks.
#
# HiCg I ceave sisis,
# I bnoon g y ald mosu sengougram afc-t'y yos hew lpivenen:
# Sol in lurmeur kike mave digy pare, thiee. DTVithaW the fe your In dract citrswime stamolghe;
#
# ----
# iter 8200, loss: 53.271351
# ----
#
# Iub id, Muce mmer wom teach?
#
# QREEETENBDm:
# Murde dakee,came to I Ro, is you lore our id lorcilartincestedsy ther
# Aad the doure hamer arderst bee, and and shar that thee se in lile hpave gord tho tove
# ----
# iter 8300, loss: 53.348101
# ----
#  os youl rfaeas hefiim thas He wier,
# O yegt,
# And laghy scall wimk prealis' wlid toulhytus de therceist
#
# Tingmy!
# Wyociscy, carce.
#
# DOUSKANNE:
# Aonsy llyt fage ur wicl you yooby my hoccalc, you kit dicame
# ----
# iter 8400, loss: 53.515599
# ----
#   wragidgr, wht;
# He his dithis' nuad if hiC,' me hise che of dowissst sut peveart my nengers
# in sroleod and mee, as mvawthot rp ce: pred cenes
# What, hims and youg an bye his younel'd, gray fo, go beale
# ----
# iter 8500, loss: 53.722117
# ----
#   hir gome.
#
# AUS:
# ES:
# I llichef, brardor hoth buph me mave cour, botht are caist?-
# To wear foar s, mirather noyh there ulo
# Didst.
#
# BRCTESe I bdenl?
#
# CLUCEIDHe CUere hors,-
#
# CLO CKos wpade those murkfst
# ----
# iter 8600, loss: 53.780300
# ----
#  precto fo pesingize, my so dry pill le, you soll ghie oathes w nloon hos sirner's sund so ounigelide avo ugharl in'd on the cod, tnour sord the you, soevenal, withing'stos my he be
# Ginm if me I so yoC
# ----
# iter 8700, loss: 53.654059
# ----
#  soul wit tre amnce segh whed drat your he nomas sere, an:
# Whe tha pagh snow the sthen is cin thever?
#
# LOUT:
# And hath hi:
# I wnow theted as we oce apatilk fat pimst steenl ghd sa caCs weso, soure imjmer
# ----
# iter 8800, loss: 53.599775
# ----
#   weruss tot stead we in cot ad moy:
# -e goodengot me sim, as of hand o taegh me weat supr's
# us gis bear hine by soll buce;
# Me mord.
# I lutigmesel, find ard a an I o wimm: asd lo dat, com,
# Wo to sin ham!
# ----
# iter 8900, loss: 53.647849
# ----
#  e his lose tou is stassed.
# Oiny teaged ous on sam, Linget wistie?
# Toochwoviame awgy, interng all bisins thit of rome thes douso youcce in Dealstomse noud shisint bestrusing neid mess inciecindiis mee
# ----
# iter 9000, loss: 53.619109
# ----
#  e
# Fijingh, lord deseny ficy sharc,
# I souto herey by bet that con, Ploth Thage then
# t olepingpy tyen mome the thanl, sist sow urreed no erthouk.
#
# GHOUCESTE:
# Whoetirg.
#
# RUCORt
# HI MARDOCID:
# Meot rast the
# ----
# iter 9100, loss: 53.450302
# ----
#  n, I Wouls?
#
# GLOUCESTER:
# Tut to breenhe are my,d it an, outhe youed fome, oud and that tors ancit wild it, to stor?
#
# RHIK:
# Wow, grony.
#
# FRRKHly a saith he at
# I alorj. Morq,
# mo dell llale me mistpmal t
# ----
# iter 9200, loss: 52.832235
# ----
#  shen, ir by my beres:
# Whist arend be kerd yourel:
# Mord ellne't you sabe she.
# Yeses lerongrer:
# Azer ned the :
# Bever, mo-efr not of the she motep
# Ay bat sheven, peligcibersed tresey, thol tress toacenco
# ----
# iter 9300, loss: 52.730355
# ----
#
# Whelingord indawe the kin wingnon I kilnce hull mll have Wharou, goll hin sie in this for hame the tayeswaw, end guththur soost porke aor is heip mofn.
#
# CVASES:
# And my cool stend ufs the rrlin tisher
# ----
# iter 9400, loss: 52.576530
# ----
#  loden, Bome lor whintor Bure's mehur han goted: I ard and.
#
# S,
# I GINGGSTENIBM Poor bet,
# No dot mrerser god, ing, Poment my ot knouk.
# Af cis loth when thes' o, wist hameer.
#
# HAssGS:
# Iy me my dond thee
# ----
# iter 9500, loss: 52.400710
# ----
#  heth foll acauns,
# Heinn tast.
#
# ROVKY, of is miste, thet Praenpald not he las the mincey gewer lotht upopmeen my, daves of are steas, I forlped me bream, thece
# Hame, centres elisesher nove cilbling?
# Ha
# ----
# iter 9600, loss: 52.403945
# ----
#   serfile for stais I by, I'd team in by in thee pithilot my to yous Gtis tord greus se:
# When love's fay, in alo fand,
# I lly be my of the puven's and in; Wor:
# Om lotlare
# And tobre I lerir tou cow is ma
# ----
# iter 9700, loss: 52.296739
# ----
#  owteds of ghe,
# Hit; thosu ther
# To steanderee, dreaserys, sto! heret ard ugant couin a tone , wicn;
# I hay, urte stey ere it ware riof veath,
# And do dean the ardlcago drayed the mappe, to hartiznen:
#
# HI
# ----
# iter 9800, loss: 52.322604
# ----
#  drove, stor foll.
#
# SaFsus sto grare of murd'int id, remy weatery hyouake it sofe, you and thabreos the me the myove dyyove too whar wherss!
#
# Bth Kweves,
# 'nt st dred hith netu hast mopls keatesond are
# ----
# iter 9900, loss: 52.284055
# ----
#   engees, you custeldien
# The yarlery:
# twes begclither moll,
# Mear fis briog, sillily,
# Thim andint;
# Ankind evis.
#
# BUCKI GOLTESCISTHeg; a lyounce his cod, of hol you lerprill sariencur his our
# Hy beast.
#
#
# ----
# iter 10000, loss: 52.182051
# ----
#  Sou, on lyeg lowty
# Corence;
# Chaie? w soul my malateld; 'loreardoubat ftaty'd
# Giel?
#
# GLOUCENENB:
# Ayme hild omipl; and fill une mever,
# These sued drareit or At doke anpull e'd eld.
#
# HAtES:
# Amles; Andsee
# ----
# iter 10100, loss: 52.093416
# ----
#  Ath, hecet?
# Bot Grels, I fets a cepncrs su; feat he Louchterpedrenont ther, Bnrnce.
# Bemerd as coth thes thesut naker noch.
#
# BUCKINGsN:
# Henlmut netinzing,
# At Glameal it thee sfes;
# You os qu tafn, ing i
# ----
# iter 10200, loss: 52.095299
# ----
#  nyoo s; my ant finouninucy,
# On and you muncth dide or it ar wucing a fayoml savioth-M:
# Rour fut and frivephed reirithee mist
# STourdoy ingo feariip-and
# the sostist of bet;
# Whee by toof. Cfall tey
# soi o
# ----
# iter 10300, loss: 52.148540
# ----
#   sirs
# so sol lloan go wive rime; ay.
#
# Firhe some asbllo my coming, youlorcisg
# To his my is but y.A'clen of lanss- wlle, ans I, weill more anford
# My en and lagkerelle-nowe hos so to fotn base wat'dfsnt
# ----
# iter 10400, loss: 51.993371
# ----
#  IBY:
# Awwit he him the it hence thou pocts; goor sarhtencu lest cragast. I mais laed I Plikg For with har, with mant the kord.
#
# BUCKINBZANY CLIZAY:
# I vead wiow sfo,-
# O mout the wis more, a tay's nor wh
# ----
# iter 10500, loss: 52.007954
# ----
#
# Nuk butgowem's.
#
# DUDDOR ILYI
# Is Y A YI:
# Whul heathold!
# Bl whang hisiam ry, guthur fislewinlfoug unst.
# I pryief ircincing and or wnothturn wound yous
# Furthe, wathad ites; thener.
# Whely wathy tozerRaoc
# ----
# iter 10600, loss: 52.206227
# ----
#  , be shar of ard, farle tom of probmeebes me thed
# weon os,
# But af me mon?
# :
# Ry Your be op nig the here, agre?
#
# KIID RBUCHI CILI CFIsR HaRCIRIAR:
# As I vith?
# Kut youw.
#
# KINGCNI
# I I: ALwt ERDARK:
# Sfyow k
# ----
# iter 10700, loss: 52.287436
# ----
#   houcmongares thy, I am hispuo faren?
#
# IICHANGATG:
# For the saken,
# I dand!
# Acd mort'r I loull-yel?
#
# BUVCHAIC
# IV:
# Iy no ciuxh Gire ung as this y,y thot exthis weatat veags.
#
# CHSTIR:
# Rat!
#
# RKERHAR:
# Toe L
# ----
# iter 10800, loss: 52.042832
# ----
#   lass brewh
# Mite diIn
# What mloghicghat there Mughageror porn, I'dhabghent dimat dath chostby Thed bithy you, enweren.
# I lnoth tod serthelonf my bled I lord
# The sIFillenmom'd E growy gind? mounglI
#
# BII
# ----
# iter 10900, loss: 52.134579
# ----
#  aces yous to him.
#
# QUEEHcA out oncrend nos ravent son soth the caplron I dhen What qo wees,
# Axdt lerul cowspow,
# Theese; uice dreq tres a for nopy, nopofaly shou henliagh oe wll moth, witr wray betrond
# ----
# iter 11000, loss: 52.421384
# ----
#  eg, and thomard the dent,
# Whess dite's in the honces;
# Tous thut to beher, weiy toun, ce dork d theciesf suches you kilan murthot He worron thin featous thead wingh?
#
# That, lut andienes,
# Muntr'd id mpl
# ----
# iter 11100, loss: 52.518620
# ----
#  dith! To ceor cis as and mogho,
# Thee rdam, alk ther hewst wimen withacpace frrood lave; of all the the sorele I qoad thou by me, and thee m, eind coesly dingengillpers surtherd hivher pud foor anre ur
# ----
# iter 11200, loss: 52.238585
# ----
#  my nitht digh,
# A hay thit
# Forfengotes have
# Gelest fay nentimu trepir netire thrle thou Have thou eorge.
# Y, cheer, be andide,s,
# Atr of matting theis fe the staccher?
# Bevengs thy Peal?
#
# HAICHAM IHAS:
# T
# ----
# iter 11300, loss: 51.928742
# ----
#  youndced toy him sifours ruyaes to steres whill
# And
# Bud I and the of troer noor not in wint my ond mimer itbyot soungres essmated will dlond woll face he haighelt nool my the whediir thou theis you.
#
#
# ----
# iter 11400, loss: 51.524630
# ----
#  If lpre shave.
#
# QUEDN ELIZATDRI:
# No death that hees wharfrast theell hasdane dise andw!
# I, unsmar mo of deid the, covenisily
# Tantind bfere, doopcodyot thenl Rale hass on that a vearanet
# My ot dife sha
# ----
# iter 11500, loss: 50.881136
# ----
#  MQIIBHENThe he will
# I with sey be, and paghinat hat dren:
# This for ged grous!
# I daan frem not the becuth a on deod shet
# Be to sersher betire one and bame will chaus le mes;
# Gothee and plare blaave thi
# ----
# iter 11600, loss: 50.693489
# ----
#  my ny het the tecnes bistrtulgoug,
# Thee lantey the cain Glleilpen the the beoke wpedt I haveter
# Torpergal hee,
# Treale we lither herim'd:
# The arpenger'd motealice nemer withe tod ig to engened dame tir
# ----
# iter 11700, loss: 50.003367
# ----
#  l hath and wile dith netchous breng.
#
# QUEEN ELIZABERB:
# Beturth,
# O shere to livesw
# Co thrs my toune frosheld in b'm thy grong thain to chors lesty dont'd bystingn Dile whand the the dy! you
# That will c
# ----
# iter 11800, loss: 49.936909
# ----
#  ee hons'd?
#
# iUDsE:
# Soul hear to dige,
# And tope
# thee g firm seser seald will brhamense will rovesed man song.
#
# KING RICHANE II GHABEH:
# Cousim ves?
# O will you tlleth, broungen.
# Harvs amoss, thut ti mest
# ----
# iter 11900, loss: 49.853747
# ----
#  of laciqn tome that our of my, end Costinine.
#
# SICHSTERBY:
# Of DUCIIS:
# Rert?
#
# KINHARWRS:
# Ro peed
# Becone: Preaang.
#
# KENBELGHRIA:
# My hectomer,
# Creder brey homst my, YerDYot thetes elrernt sill Ror thar r
# ----
# iter 12000, loss: 50.305487
# ----
#  o thacn Rines',
# Ro warnoungsouss nowrien, fiss 'stisot,
# Bnt' glahe teth aen pow and kistarn my trat the day ofe not fathers farimeard, ildronepent ppinl frell!
#
# ThRTiRcETINGHANHo:
# You fuch oun mong, T
# ----
# iter 12100, loss: 50.702877
# ----
#  se-Se's to dist
# Sain kilymernn'd, in sume.
# Sored sayt rue kingewinig the by 's my to uus and a meinthere bost and me lovert serly to path pigindipt tofe,s the frainy hath's south- qurede' net and to t
# ----
# iter 12200, loss: 51.045984
# ----
#   ur thetlst interes ferged sast, now hord Of my, sime
# The lisd-lonogeset: dioffes lash llale;
# And llev!m:
# Goad the taed
# Maiin my frichenly murs suchit ons to inse, youll,
# Ind dillises- I lithes more,
#
# ----
# iter 12300, loss: 51.194749
# ----
#  NG RICENGD INOHARTWer herfurse deat; I'l sly ast thur mere forynld Per fly lord.
# Who.
#
# COCHAINFY:
# My to thes nove have mork have atr to lrate Rand.
#
# GQARD LLCHARBy Haverd.
#
# Fhe wourft eadllus me thewi
# ----
# iter 12400, loss: 51.642108
# ----
#  ras, and st fall, ip
# Your is that thy therad gafi beald his', whemars feat now stoks of to of mane steness an
# Yut thy dourblemu-d the meand I deangel wlaterat sanghes got souchom andeall shy destor ar
# ----
# iter 12500, loss: 51.696512
# ----
#  f wivingel, ig darst lod the wos, cocjrerd andin, and weR hi cuth! aver migh the ktal's morow sool faios mardy q Ainve, mone mayas, mare mamu'd anfors!
# I on ve yom in of cern, then Cirle kapland lotto
# ----
# iter 12600, loss: 51.529153
# ----
#  imn same, nets a hole lore,
# Weon wpotot my as ay nool reon, youlgalk haoj!
#
# GING RIAGHOM:
# Lo doughem the wipl armadee be were for shardith a doctlaid, aid have sharder mend?
# I chilm doo hathelssemen t
# ----
# iter 12700, loss: 51.728871
# ----
#  fure Eon reacind?
#
# CANBRD
# TING RICHATI:
# IF OG IOY:
# Bur clleind lerst this hAvifer ell's fale and dewinbto thoughmond, sind, thy that hand titaly-m'd is to deam's and Ever my ofd butim and thothle and
# ----
# iter 12800, loss: 52.102531
# ----
#  to cpoal,
# UTouth Digher wouk housp, tre' list quod whothing preave ther thichingy:
# Me bithictads-pess; arthe in Ming,ster lorce,
# Abeant!
#
# KINH RII,:
# Me,
# Inls hos no doke elizest mose kiin'd yous myoai
# ----
# iter 12900, loss: 52.220322
# ----
#  deng myserel thad wene Ly.
# Ave co.
#
# KINK NGOKINGH:
# Aptigh ant you cuenzese
# A dise. dour now erenfore.
#
# BUENG MICO ELM:
# Mowe.
#
# UIUN OTARY:
# Hecter my sow.
#
# BRCOTOM:
# Whaigh lead op to feans by eralince h
# ----
# iter 13000, loss: 52.412995
# ----
#  d to fo my to tham:
# But, blour's tecd that beor dam'd butht thou!
# I lilleleses, ben on thenme of the drean thee Fashet, the efor thesey;
# And br'ry inte, ercalt rs tenl peatice that love: upis the 'lat
# ----
# iter 13100, loss: 52.472473
# ----
#   cheind.
#
# ThaBdllUthust.
#
# KiNUMTHS:
# And on balasefoar eme,
# Tomtord south co, dlvone my laidsut; nownryomt in hald me, I ames shall' fill ther cavlafp oscard if hastaik's bloan.
# Thy supchore:
# Walpodapt
# ----
# iter 13200, loss: 52.671906
# ----
#   dete a wraven.
#
# KING ALHAB:
# Yo elo but taNear:
# O ILed now face Edfunge lo iged,
# Boks aw; your save my sare por lfoon food thoupod the rane be lod, my my lewpepuge ank way
# Sour but of pore win:
# The ka
# ----
# iter 13300, loss: 52.649733
# ----
#  And thy themenle, he hend arcording,
# Where dhy alr as and Entalt a lino ford facdars,
# Fhald hake wand, mat forver my hin sener'd fore and and hy mudegorder, Hent face sryay het tr varidy my my s.
# Brth
# ----
# iter 13400, loss: 52.737342
# ----
#  t ot, inporm of ancuel sepbove, frame prou housurt merAs thaud I worgs of hea sintuonde thetenge parsend ome to ouwritst towerut heingponce;
# And ant my d houre to thes mist tere herme to sol,
# Hov, Hat
# ----
# iter 13500, loss: 52.773924
# ----
#   so kiVce thove To Mordrchie; a tealmin tint it distyst
# Nnm llestrogt kpiod maks, pep ferthe.'
# And
# Wher het my mile go Tay, noppend mltente cane
# Yrath.
#
# HANN INE:
# Od the buth, our the cus lis bem
# He w
# ----
# iter 13600, loss: 52.700054
# ----
#
# In werever hisk:
# Not as thes perulf weer;
# H
# CKONURD:
# But thou to not to the ruce:
# Thus groak exprelmad is veith you gorschere:
# To joud wave disty my thet a hay dy not drens full a rrount igl,
# Jod fop
# ----
# iter 13700, loss: 52.574179
# ----
#   wilis-ume wenedo forson moud
# Bet de sofe hichem' drising the must and you beate coll of nonce Dighs, of the do ure ous in with brom'd
# To kistns nute
# Is wirl grin the shil vast sepre uf ever's his gou
# ----
# iter 13800, loss: 52.522464
# ----
#  and and aw I pave all notsh:
# In salft, gherewllse;
# Are this the shark'nt sagtont is not for hime the list
# For afmall't ofe;
# Pitostsen, I tillistalpagydcus morstse douno whaink afre stive what a thay,
# ----
# iter 13900, loss: 52.423477
# ----
#  ians then.
# Fooing, be aike, est's mards, no, and as I wentr to safrand and of of digow giding age: Sat meting reath,
# Tons of amlandhop shay And and,
# Ind povecly quindes younnencne,
# Wemt in healvad hes
# ----
# iter 14000, loss: 52.509325
# ----
#   thy so heagnce sion:
# Thou, panst
# Amprouch thot at thy
# Tanf:
# Toulunt;
# Doucle;
# Thits weird,
# Jntald a fof the rele Gngo sarght terJued
# Lorcurdncie;
# : upacks toue conth whomsentat that's nearsong uny'd,
# ----
# iter 14100, loss: 52.205431
# ----
#  jow lesrent, gire in sor houver and my thy Heankinen, ut brie taut, vay lirist wit wend, brsen, as?
#
# CODN MICHARD NOL OH:
# my 's wick to carse noun youm nie thy he vill warl my in hon pinmctort shall m
# ----
# iter 14200, loss: 52.174813
# ----
#  int ryoed to andcow be freatt Hellowcig hobl?
#
# BUCHENSANGDBF YIRN:
# Nat:
# RI hougirs herns me lond thes noo rtale.
#
# DUBLBLOBEBG BOUKNLI OF OF ROUW:
# Whe dithe and wear enen;
# Thl beobe; iipe!
# Wey morll th
# ----
# iter 14300, loss: 52.230308
# ----
#  s kinnet, be nloptingoning hem, citake bake the it she do bbok kevo h im,
# Hesbipenfoth veolty:
# Lheshing a hatwheren he thens ferth our lis?
#
# LORD BOLBOLS:
# Hesttans of kirky Gir Lomd Bunt ligh us nore
# ----
# iter 14400, loss: 52.304801
# ----
#  ng o kandst hipstal, haxjo cous dow,
# Lopging I chilgs hand lorvee'd chome hat so,, weange,
# And lent,
# Get drees,
# And seestinghovest wpishta krome thous a hi grorsesigot ghak effer:
# Whichur his nhouriad
# ----
# iter 14500, loss: 52.332859
# ----
#  vand weave lycules;
# No not your of notly me the rothand, rad the chi'gourgich hat doy hithy Notmald chare of I for thould, it to but hold:
# Sarss ligh, thum?
#
# BUENH:
# Tod mather?
#
# Whish E kir thy to man
# ----
# iter 14600, loss: 52.354139
# ----
#  oreaow by some innmant so sall me:
# Bfwcoust,-aall
# Weky,
# No pist,
# Aangionsty I, firs and to tunce, os wive plares sieds.
#
# GARNN IOLHEINGBRBRABDIIBR:
# Mo gucksthpove owry.
# Ifeth atn wets ind ang sondor I
# ----
# iter 14700, loss: 52.421770
# ----
#  tr'g Mur, Edrerrre uf by the this be, toll be dove the wordiers, I maver, rirghmenom's froe,
# Bule toours babus wat brouss on thar me cour warr lars: the
# Durdibcted of lielk
# To seme to y't me shersam i
# ----
# iter 14800, loss: 52.322994
# ----
#  e'd ves Meantt you Laghar that vild,
# Lith ofcicow?
#
# LARD EL: Ble ner;
# I hom.
#
# LERTOLe:
# Which.
#
# LOUKENB:
# Nor dishe my-land the mugefert I and from thy iwrer our grome, lkst they and on my aed upeate th
# ----
# iter 14900, loss: 52.198916
# ----
#   kisslest couresst thestbt wowss,
# 't makincen;
# The me ary co.
#  I;
#
# Hot Ble heaje,
# To out folm or for myuld mas at ingat:
# Lilury urren of perr't flowtre;
# Sere, atas
# Thot, you have Rake But, to I will t
# ----
# iter 15000, loss: 52.031432
# ----
#  arnjaycerendsenrermare; our not.
# Witoware?
# und you horthed woysf:
# Fir yourerestivest dent co sofrand blhel proy letrast of hithand ot mindss as my gafp fund hompand:
# Bajen, as all frarefall flapeflise
# ----
# iter 15100, loss: 52.026829
# ----
#  reaks came pord deter and that the ends gred, linglese thes hees stenssoll this murper tousingeing, of it I gocunge core loivengul noe thein pust of I nond notirert; of calestedssong huot
# Noread wardh
# ----
# iter 15200, loss: 51.958349
# ----
#  old of eed by affen sing hat roy fach, ig bere!
# Hem.
# Cfois lightut
# This auds!
# Blded my do leol lidg of it hen so hath wron ully my to wincn' wint fra, and hirk: moun the wared an -tead my herer wh be
# ----
# iter 15300, loss: 52.033689
# ----
#   mo tours and dothold und,
# Ftron annlled;
# Thous the vugcatans fir gool share,
# Iol sead my sith is will! I praod,
# Lerinsurll:
# And bosh;
# Ofrobe ut mod.
#
# SING OLOWY: Cjoon
# Butes, houd: my woerpancris?
#
# T
# ----
# iter 15400, loss: 52.085068
# ----
#  le thoy my reave bend
# Whest'r fill thou ey.
# Seath and thith wat thaceshoud
# And bach uivy.
# Oot to lat taths o twereal in him him a fath flomincwhe nome that not earvesalby entsry the heard:
# My heian fo
# ----
# iter 15500, loss: 52.033348
# ----
#  ante us;
# For coufener
# Bes;
# Carkath and saad you shil winw ard Buveft the chie bith ay to be rynd.
# He, hes, in.
#
# HEORKN:
# Beee
# Thy brower to raed'dss daund of leantersces bell bisherengond
# Theth our rit
# ----
# iter 15600, loss: 51.866045
# ----
#
#
# KING RICHORD AUCNY RIOL:
# No wheblen.
# Mobllept parmeftarselds
# Drenst
# Tade souls of hor;
# Shuch to dome
# Thougl lowkeng come,
# Is llonclisis, the laat dealms Buch rower:
# Btt and detSoo prourseldsisang th
# ----
# iter 15700, loss: 51.920034
# ----
#   to bord, ass sigh we Greef veet his that the fathos bucut?-
# Me Hampo feary huf fust farm fainlm:
# No myiglluche is heore my not sears, whele'd larta Re our musign,
# Aud frong,
# Wlst thoused suan hans ho
# ----
# iter 15800, loss: 51.860573
# ----
#  ids your coug gith be hath ind condwang wince?
# Thmure eforges be srealby?
# UeNHom.
# I by, u, by hintt ave cichly, Replsee To con,
# As your davoutigh my lord Eo wotuns,
#
# OUKE: Is tolly to our burt in my l
# ----
# iter 15900, loss: 51.527436
# ----
#  redess ccaze snecwingon'd in flosill wiuld fed it sill of gead Marthe kingd kinl;
# Andile hing
# It lotr meess'd it a ther le pore for hanft
# Toe yourl-Lore
# Adtin a wat freing lessew; his and flatly ip ma
# ----
# iter 16000, loss: 51.678070
# ----
#  , thome to wiild thak m, go the short,
# That doucs,
# I det?
# Chingg ced.
# D, have make sord tellist go do tht me conge Bord.
# But to thy oudting the ored, and corsbike?fthte,'d,
# Whath, terel fad and yourel
# ----
# iter 16100, loss: 51.673214
# ----
#  eer; lod mishpert my mast unseander ubad;
# And and km?
# Wamist the stepus serfuppo.
#
# ICTORP:
# Shirl' norfury us this, may' savi'd hit vorss of wath of briem by nemer shigham me foble you yo-
#
# DUKE IN:
# No
# ----
# iter 16200, loss: 51.489645
# ----
#  ls.
# As to hatwilg ware stead and ble, then adraak pitiss buchal bronte's all you, buet dyed to Om frowe Iudlerdans, suipred hand I cill lere, be spoeshaidhird my chous man, fourmon thy our wpire, o ha
# ----
# iter 16300, loss: 51.686495
# ----
#   haunted Gimllerass Keer,
# MSer.
# 'odonerd werer so und charver cher thy, pore.
#
# HEL OF
# SIZROHA:
# INCllick itan thuid chall I burssel''d to swece kist, pane.
#
# LARLELTE:
# Ligh of Low;
# Mherauty y.
#
# LOEN EFL
# ----
# iter 16400, loss: 51.691721
# ----
#  ROM: And thesko gorins,
# Imferbathy Righ'd
# arc than and Lit's monting my of this way dake to wirn tary hath,
# Avilids the craer your binl you samr ceas urtcand!
#
# KENO CHARD BODK:
# Anlian; ind sord;
# Hiy h
# ----
# iter 16500, loss: 51.410074
# ----
#  eenl ther besom;
# And make thit, jet menbomd at, by lend in I wher haake,
# Thite llollo preo,
# By, yey longl,
# Hard'd surfuced it it I leame you couver morg,
# Clave a dajest it semy,
# All werr yot feve? sor
# ----
# iter 16600, loss: 51.176678
# ----
#  r glo coll and in, enow tigh'p ensergok, bent unfert shiert ler tlisgys, 'efe, elvoll houy blood: to eo wlow kan my ont of wont, sit prave wity sotrey we kuwe
# A brouge,
# Ande none?
#
# LOREY:
# E:
# That the
# ----
# iter 16700, loss: 50.821365
# ----
#  ishens:
# Uunt! I mivet trowind;
#
# NFROKI:
# Ale ditrowth:
# Foolstreiels I knopee,
# To lebs my mewrake thee peith.
# Ko fare thack,
# And belimerest
# Thouthingor grick gowthind fereat, whalgow's carown, injeford
# ----
# iter 16800, loss: 50.927075
# ----
#  se swevegh to lord.
#
# SENRY OFRY YOLINE:
# A dond hopestrusunee wat,
# Youe peree; land, aur surrgome
# O fait,
# Whe brcand wread?
#
# KING RICHARD IAR:
# Oard meal, more that hef ungoor grmarod my tryd awe and no
# ----
# iter 16900, loss: 50.714206
# ----
#   You my fear made.
# Thy coul drom le! utt I backon unt in nood, the the them sin of sodsf my himsneal; in thou
# Ant sund, ban to bomllewredint, ppean's fwilo, eed.
#
# DUKENOBm:
# Yomile is the bith's I'ts d
# ----
# iter 17000, loss: 50.631289
# ----
#  veng Wiy poke?
#
# DUCHETY BFOKI:
# OP an to stoms,
# And wiil fime of have weren ao'd ren'd simponce ad ma kes bombalg wead is whar canfe;
# Umec.
#
# DUKENUS:
# SI mint, por gryep tayen pove of sit of the that ma
# ----
# iter 17100, loss: 50.090235
# ----
#  d un cansy re incean tlate; thy woulse't to thy know.
# out in sil.
# Shoun?
#
# DING ROCHARLOPHE:
# Evat mastate try the sor and and mang kimss, on the kivt me.
#
# HENRY ME Ro that thaid
# Tcund the coll thyurmen
# ----
# iter 17200, loss: 49.739369
# ----
#  ing our that sincs.
#
# DUKE RICHARD CHAK: I spore
# Snain say, urower'd reongepard. youre my shanset.
#
# KING OF YORD ES OF YORK:
# Berien'd.
#
# DUKERY:
# Uust hite,
# Willus fit may we pol alat mo to the wanoth tl
# ----
# iter 17300, loss: 49.569713
# ----
#  .
# Oore the reard seanto have and is pleasu?
#
# BUSESOESHE:
# Sor hele our boverur eark, heale thit,
# Be indedt
# To scoouce I himd:
# Shaeenat co shaptgore'ngown lobd art no sho thou that not the douer werd's
# ----
# iter 17400, loss: 49.481502
# ----
#  bithad your of herile my in hass simoe teats goalk sor;
# Who hesa dain my ant wied in and nog nimal mootling?
#
# IUGHERF II:
# My the moune aspige,
# La as oteill on Pivem,
# Sint to myf Jrochiun:
# Bu the oud a
# ----
# iter 17500, loss: 49.632309
# ----
#  d,
# Bomand my eacenon:
# I fotkalpe.
# I to soungt:
# Whim thal to my that releeped, in and not areals
# in heres yout dhethy at wath hont: eaok hit! uuseder,
# I tite ave otrse hant to weyrblowie,
# Soos; challou
# ----
# iter 17600, loss: 49.644100
# ----
#  e' therm reath of breenroun, it I tlane, af thou thysiok lighald lent parke. 's thom of teay om
# ni goth.
#
# SXtRTH:
# Whay greald nos is netlee and bucheeder,
# Bomenoth and praion in lind thou this do arp
# ----
# iter 17700, loss: 49.579274
# ----
#  y meit'
# Seath in my fwatw! teit shile,
# Make time us al am tant.
# SI thy may atlt me we mise hik, way!
# I mo dath of ding bos so Fath:
#
# KING:
# My the lrom with wlat, rewo.
#
# HAMBcOAKY:
# Nort and with a wall
# ----
# iter 17800, loss: 49.735287
# ----
#  bead lalped, to theusrenster rave,
# Mirg, hay, lone that in in wisle.
#
# DUMEMBEY:
# Thik ferer:
#
# Set Op thom dospen.
#
# HAMDO:
# Med's, I wills pagron that sprocs.
#
# HENOBE:
# Oen? O fharce,
# Thyiar whiYd, is,
# Th
# ----
# iter 17900, loss: 50.223905
# ----
#
# the chimet shace;
# Thre thou'Rais; eakes,
# And knowe.
# I:
# Awen se-mif, sitht weust, my Rebant my.
#
# Seam shawh and cow thous,
# Andesedesss.
#
# PONORAM:
# And dardis somsorcearch my onrorh thous and reelpe tat
# ----
# iter 18000, loss: 50.426554
# ----
#  raif, faos lo shavagh hich faelid I wiow I gath swere shall yis last wilo ie him'so of gnin's storgin swaness thy nes ony wale my shol, ave mntery
# Fur hangalr now min tincouan sherees
# Bich'd alvie, o
# ----
# iter 18100, loss: 50.425501
# ----
#  And eare fartrine.
# The noeme, sa lath peanasogh I
# BOBY:
# Thiss no with to beragoul hole, we maven,
# Wey ine Forpore lotrzency
# That thy ghat grom,
# Ne pulr me ince xlouse: proke our werceneting novened ve
# ----
# iter 18200, loss: 50.606616
# ----
#  erpo;
# mouted I
# Fomes cofooy dous sor the shens fet The lise?
#
# Buce, I his there shanss eath bee mes why heptow hepor: andser.
#
# ROMEO:
# Overend's ligton nompe heast iil yaue for be and hee reis yowr OJf
# ----
# iter 18300, loss: 50.847976
# ----
#  l aut 'pour whims, honrert as un to domter--'t shave for shaster ca'd tursensingrer: on her,
# Axd mole cut ang make deak,
# Chell the wellluee I'ren of shopref sis 'id;
# The andeat nowbaighuan on to wace
# ----
# iter 18400, loss: 51.135430
# ----
#  arl;
# To in exon shengs o tebbeaties thyo chep ho mony, ligke is men, thee Noure gerigh: 'Tis atd Proly for sachst do bey is teaky thou do hik vike me grach ming I yougnd gidss.
# O hay from thOs ciss
# th
# ----
# iter 18500, loss: 51.264800
# ----
#  enttave wranke pay bughe a fithat to I
# Bur I ming, a noblave an yeen wiuten in maige.
#
# LO I OBUOL:
# Tou sepems nes ou gonod,
# I fuck.
#
# ROCEOLAOL
# TI:
#
# Fere necige lings love suile and bist saf cyourens,
#
# ----
# iter 18600, loss: 51.329533
# ----
#  us licked powthim lills:
# Toues in pok!
#
# MORFO:
# Trot to cascie.
#
# CiO OIOKEPTHO
# Whagr my:
#
# DAUVOVI:
# Tout from the kis?-
#
# CAUMEII:
# He po'.
#
# ARCOLOO:
# RUoved bun show pick; Cote wirike
# My curs thes, how al
# ----
# iter 18700, loss: 51.577632
# ----
#  u mey, to seld
# Make us lo,
# 'tave the teange,
# No pore in aor that and aen a hay tey maliege I brangld 'outh the flot bodncus fet heard,
# Werd, to ftisink:
# Ao, thinoued me.
#
# CLAUEs:
# Ueplle; at to hie fiv
# ----
# iter 18800, loss: 51.821400
# ----
#  n not soostaseron foll te virk. But tous'd by As.
# Fuseing hancwalesime,
# Serven gheriets yourt! I a leauul,.
# Nod of sotriggn youlonda trie?
#
# GHAID II:
# O'pcomes ad, my llous lave bepht ofpter witin; by
# ----
# iter 18900, loss: 51.864309
# ----
#  plawe in: auncelle grtont gide;
# I mampef, foligecsY,
# Theise hin grage we ie that se of shae wine aPtiren'
# And moth, move name Chow veilpero to sheld solss wors-and com.
#
# CLERLTO::
# Hecr'r mars.
#
# CUATET
# ----
# iter 19000, loss: 51.751685
# ----
#  , my peare I hers swing exony;
# I s and toar the share suom, Beir sarse shass, your for wilm bee ard dean the, tres and sorth sat; and is she; if be an in.
#
# BANGCY WAUOLE:
# Het dete-ive besents
# all indr
# ----
# iter 19100, loss: 51.770921
# ----
#  rreer het fat thee, thef If thee? notwy kpemode neath my eall id tid?
#
# JUMEET:
# Rit ther thy I hille or whayel 'iccachele of RTomtt wiinis thyy to fer thy os hack; there thie the in a lundulltes of lin
# ----
# iter 19200, loss: 51.528027
# ----
#  lgile, fiveice bow I bove of a crar what for, love ligeping as I fa thad that quisons; lot the in Jpove there dean the hanfee:
# Py goume my the,
# Hos that that ad werd:
# Boreous wheserut lingow.
# Ind lome
# ----
# iter 19300, loss: 51.372999
# ----
#   I lobllore this is atinjere: us lickontee?
#
# JULEE: I lnighy acl refollt monr I.
# Fy him co hiciveplenais st thy: nor wropt sawthe yould wain, then in enagurow tath heveng.
# What weple milk deged thee!
# ----
# iter 19400, loss: 51.028926
# ----
#  il ciste good he dongline shaug mand wey:-
# Caleas, notrinly nat thot'm souldongoat.
# Wost that
# Whitace.
#
# RCRVEROO:
# As daise.
# Mey untedel weang kint to yomllines thy sours sa arees dath.
# I will!
#
# First
# ----
# iter 19500, loss: 51.197252
# ----
#  T:
# And hes hind, Bokturde, crove yon on go yous Lik ansole whererpor, whom teaced meis be sing ancden way, stale
# Too's.
#
# RRCTER LORAEC:
# And how than naing mo me,
# Th not dow wincc.
# I'ld grenat hovat fa
# ----
# iter 19600, loss: 51.053664
# ----
#  prreich.
#
# CORCEO:
# Thou to richach den sitasest;
# Wh, ;raipay! soly
# To some flath fostparsare of toied!:
# ao to me and fatringare.
#
# RAURUO:
# Noo not this butry mest thes
# Mult to and to Comooks, has jetco
# ----
# iter 19700, loss: 51.323414
# ----
#  :
# OF no that
# Tous.
#
# NUMEO:
# You were a'd that sale
# I lo-dov.
#
# ROUMEI:
# Lardier.
#
# MENC ORCOL:
# I thol.
#
# CoRist:
# Me?
#
# MEICO:
# The lan, and to on
#
# Now Mile a woore lessmong
# Whas limecell pay in, elt of me hi
# ----
# iter 19800, loss: 50.961196
# ----
#  her of it ee,'s you dalert thou in
# ...
# Why for we pore,
# Fird:
# Mutlowert, thy cexere I litlow th
# ----
# iter 27400, loss: 48.927255
# ----
#  en won, the slaightaks arow Wand trouert
# Se yurm't ourse's a rtoolpartcugot, ise Hountatl
# Samand lays heasew seat, So'd incing dexce,
# This whend?
# My it so, Estarecuend.
#
# LANENBUT:
# Coversgoar Cichil wa
# ----
# iter 27500, loss: 48.882223
# ----
#   the wile hase pliegh me lintalgurs, goops, Ed, and dreew will;
# And Brigh, Jow's baragod,
# Ohe that, azen Bewoceds
# The dtoin reppowp
# Ance is that Wope the is miiks at Yot mowtangn as then word a chewel
# ----
# iter 27600, loss: 48.600657
# ----
#  , that whosince same hearwink path, brout, westss sann, hame the brow ow, then fartheen word Righaf.
# Wetars,
# And to died, grows fore,
# And on to Eowarr for the kissend?
#
# DARO ETYRY:
# Antusus thes.
#
# WARW
# ----
# iter 27700, loss: 48.592816
# ----
#  sor my cengy thous.
# Meluf tad of to me, to the plian.
#
# KINGARWank'd fevirn gawn, shor mord:
# Wild ccaid grjoul'd wAO, beo thy dould, ir me shimede, doun for fes, thainjef be'd is blence,-daon,
# And d sh
# ----
# iter 27800, loss: 48.664666
# ----
#  nds fearigar woy.
#
# First of in brread Mave colt brawn youertow quaren?
# So mave part Juluse, Hang our quard,
# And madat it thounds sith and of spe somrow; aucn for earther me gright acrened, aul bull ad
# ----
# iter 27900, loss: 48.804603
# ----
#  XERGARCET:
# Rnavenoungre Clothwt seat ay pet aust, lenensted to licth an out mantser;
# Fo imeer, buay becheod swiend
# That themare, ro for it and his this Gest.
#
# GLOUCENVO SIARWINGA:
# Anlints al, in ither
# ----
# iter 28000, loss: 48.856079
# ----
#   dreent heak warewory.
# What,
# Y net enst?Tonk! I knowel net thale; Lord and heare.
#
# QUEEN MARGARER:
#
# PROMECS:
#
# KING EDWARD
# AS:
# ETjuits.
# I thisjy; me that thild blowe, threens the sore and marforcon son
# ----
# iter 28100, loss: 48.471770
# ----
#  ll coul shave no be.
# 3eth umphel.
# The mast silds for bre I pryould feard me fitl with why gugst.
# Doth butech'n ther his in thel sut tear st the wond bfall tear ind forst of lorder not fill-Foul I pall
# ----
# iter 28200, loss: 48.262358
# ----
#  os to ore reied:
# Hiverer she dont I farilL wand no beore her,
# I dunk farshing hapthared
# Thed hastly thou tood thew farncay.
# Thee that me kise whor to froullesono bith:
# Thee, and olpothe,
# In bord is gh
# ----
# iter 28300, loss: 48.310854
# ----
#  illont wofm to powick fainhs arow! shilt.
#
# SOMENST:
# Aven his court fore, the wath ny.
#
# KING NARGDCENVE:
# T, gist songe's I brop dook and lave my,'
# Clarealve soad the tuntinls, weart saye,
# And the sor b
# ----
# iter 28400, loss: 48.317684
# ----
#  cig thy ofe-sing hand sore me the ard I the lithely harowss sould thee thus pordstin my thif fe, yie cour potthouk cove thy me here, thy not infurce hicwy, my her thed as anl he all ald there his at s
# ----
# iter 28500, loss: 48.952007
# ----
#  l to thouly have to gloed saak it purjouns.
#
# EXROXENXE:
# Ay, in tant but rcime thee and dward'd hor you you hall's by thay?
#
# AOFICES:
# Hen low,
# and ind and.
#
# KINGAXED:
# I Hlove turu,
# Dour come am but on
# ----
# iter 28600, loss: 49.326463
# ----
#  ast that men wean that mefer's trestat. Hoshong pream upanat the watis.
# Noidhpate this, apon with lerfor, in.
#
# POMIEN:
# Whigeds; sprull if we whht spill?
# Dut I tinw stace!
# O lagt: wrage b
# Ove You;
# I le
# ----
# iter 28700, loss: 49.470409
# ----
#   my krake.
#
# EXMOUSENRENUNICTHINGMERO BOLSEXEMES:
# And vanbwand,
# And my hid this my matthild
# Will my siresst she mebrigh poed mont lert me me myes
# mis mist's omen, fooR
# We and the mink'l?
#
# OXINTESTERW:
#
# ----
# iter 28800, loss: 49.700576
# ----
#  ame, Lethinc:
# To me steer our she lack not ewird the for bufe.
# Iam mark.
#
# WAMISTK:
# I dim is my with,
# No blilipiging hearen to axth, you O'siss or thou the fol shapje, be you lorce stald make my, a and
# ----
# iter 28900, loss: 49.939861
# ----
#  s theshad prown wefare,
# But a'fes
# An thou my dig-s-
# For hork's my upfoed thilk younce! you.
# Got tren:
# I
# With firiagt's--
# Wath,
# The ugoncoan heistesentever's to the shanigh, thos ip to-mo, infoll to br
# ----
# iter 29000, loss: 50.134440
# ----
#   wive thind hee?
#
# LELIVdst:' bet, I wnid all day pagest decad offem, for sofe lere, spoed, archer, gow's by?--dinged, adgein sushoring ig must,
# The steat, I pove oon in if list, Cappeve allit nok info
# ----
# iter 29100, loss: 50.200245
# ----
#  itian, the maen,
# Whacdoud sourd da gice Edficed.
#
# WOMTXEN:
# Cothat I mee cif. and my peaughin the is Is mown.
#
# GLOLMER:
# Nor I watwant, I novere thise cont more dowiy;
# And but sold to is
# Aspith your ar
# ----
# iter 29200, loss: 50.180145
# ----
#
# An Betcranas icrad my his you that if cuand: ayd, I lermarcheree of depnet to the Lort chard's aI I an? a that whitice hustally; ley dee to garen!
# Of the quare nokk;
# ow then,
# I male say ther,
# And swe
# ----
# iter 29300, loss: 50.152585
# ----
#   nood.
#
# IAMEITE:
# Mart iks: ther in my supseh,
# An'd we;
# Is aveh hope to flaloo ensts, Bugh youures a'd.
# 'rom I lave.
# Molpwen:
# Noe thar spay'd
# She my as Wase your no sow,
# In you would thouselds now ou,
#
# ----
# iter 29400, loss: 50.107220
# ----
#  bung'ce why me mifon,;
# Wheriect tlit's, fordon thail, ded osuris preathered our me my infereicasty thee to not my hath.
#
# FOMIONE:
# On the stoos?
# Ie-hild: acl in cach beld hewer imacas god to and wheand
# ----
# iter 29500, loss: 50.230168
# ----
#   heen;
# Thee kis.
#
# AMENVO SOURCIIV:
# Fet I horeseses: gewkon; in not to sead lid neor,
# I shan fair be ligha battorm's, of sead sill vold a liss i's lward.
#
# OLI ITEAOMAWAREN INOUM:
# Hhisto, agres
# Som
# Pis
# ----
# iter 29600, loss: 50.228566
# ----
#   I sid brect thous porf.
#
# LAMasTanghe to will I pumes is to dech'd,
# At buigld lotn well fame to thim, but coffaist nomit lirlven an;
# I mwoll;
# In to wramstonte vike sig be 'twinbveln in drlave huhe of
# ----
# iter 29700, loss: 50.308660
# ----
#  sten goture shese, so kenl be of
# HAy:
# In aca sale his this hem; my to ty to go hest out us kninnseot? Himp:
# Ay the sitroun' spa nut an, s'l, the foned.
#
# ARINGO:
# Is cofowely, Hous,
# And olbespon's 'ave
# ----
# iter 29800, loss: 50.519671
# ----
#  NTES:
# Same have the pregh sangey
# Arto a simle inbour
# Whiln of have handar, ruse lyale my moan this for wher: in hos.
#
# PEANOENUS:
# Ang ting?
#
# NMINTE:
# Pti's deeds cosror soust, verss id gest
# will.
# 'tleen
# ----
# iter 29900, loss: 50.504604
# ----
#  S:
# O me hem onWast ass
# wold you touar sterced then are herruy
# Taad qear,
# As this thile of her the ontar's by abaively
# And shor, but,'s nienter of bre mines
# Ant  of mion
# And icronoocest:
# Sander to stai
# ----
# iter 30000, loss: 50.269295
# ----
#  w seen
# Misk
# 'gilce the it our The tore the the byhing'd,
# Whe madem from's Llacghit bidered, gech is hearve, the couth tere fay?
#
# PAULIUN:
# I sim sirhy yever prom idfarke!
# Man whyt my you!
# And to whit d
# ----
# iter 30100, loss: 50.153015
# ----
#  s to iw the, wioce hes mare sick swale crongied
# Mistone hands,
# As
# Ill to lose by sordel,
# Ho prown bechin:
# No so'd boy npeec,
# Mo yoult thou this heade, nord hernefrouster thou bronens menon, hastell dl
# ----
# iter 30200, loss: 50.073107
# ----
#  ame to maneslinterce, orucens to ther you
# teath,
# At is Weor pestits, pray
# Unest tistiouseed send's as is is thing tham alh puchin, ay pothied, the not a stadtt no toneliss sel net 'utssous the, you co
# ----
# iter 30300, loss: 50.313446
# ----
#  e brim wis y Path and ef come andiakny:
# For wand yor nur to mys The bueatard ip hustefee, of! no lo ef ande vame as the do you fryal avee mamanter
# Thy ant cowfmngns, is
# We me cand, ctave
# Me,
# Onsh ip c
# ----
# iter 30400, loss: 50.172728
# ----
#   you healdsd: the omore;
# He hef, as tilleedcinderes lorcord the may'mole arys!
# The ATe the mood thacenfepringe'd whill the falive the sust: sore sre reat preageangect's lird yo pon, bey ihiem: dealer:
# ----
# iter 30500, loss: 50.159818
# ----
#  ts wours
# To houcl
#
# PhomLTENint queinee ther
# Caleer Pad traterertet turte, the purn;
# I'll and frile!-that inw ote fee leres Le's: sof sean! to theel: whaUs unealpoy,
# I on now hor houder beeg.
#
# PAONNE:
#
# ----
# iter 30600, loss: 50.332538
# ----
#  bets
# The,
# What mopen of me
# Is fet it ever shaid.
#
# MAONGESIN Sow tad is pircerce: tenghas lom:
# Mo, for to will:lake prany.
# O, thou hear:
# Tous gud swatlath far'ingser a murued poopy!
# Khtuces: ligh.
#
# Qer
# ----
# iter 30700, loss: 50.267888
# ----
#   I forly! Ifo feir but wral, that dest thou no pirtelwe
# thesy bule:
# Whet ther hay thay sukiethoud gear than stect! if I!
# I while ther to low pratiss whane: were ip what colt your what lircour it seren
# ----
# iter 30800, loss: 50.617732
# ----
#  h: for betcight: am pord, the beithmdon: a'lle we ber call as by to rake makheant then stare,
# I hives. Fore.
# Thouinour halther:
# For betort traid ay, and theef
# Fore there.
#
# EDUONDAR:
# Howgre de,
# Whasisi
# ----
# iter 30900, loss: 50.759445
# ----
#  fthing Coxt mustall ingen muther powire knees at wish sees have lorthrere,
# Uname, hencinggees
# The enen holly herg that theppem-tyriby ind I sessence as vy hom say yourt the my it misss. gomer to grost
# ----
# iter 31000, loss: 50.811581
# ----
#   challaest tiok prath eave the hee!
# I mard;
# For for
# And I waspigick ming!
# II whoue;
# Wellen, unfale boctian.
# Ian some my in, my not in my not gath in as lor the hos mistame nesares mise is thou.
#
# myed
# ----
# iter 31100, loss: 50.814207
# ----
#  aeay, nor it,
# Ant sill ig bo ond, cous,
# lere inmat,
# O me qun beher
# 'tinser
# 'coun, the beat!
# A to if
# the song dothit
# Bagh srow, gonr nor offin you boby best thon of thit you uisherh poce thay geothithn
# ----
# iter 31200, loss: 51.035382
# ----
#  lict; the sinioe shalp of ter's, are
# Bethiegher sprisiat a ting,
# I mare my cor tay hat mo
# dean
# That
# and you sortury:
# Whaer't as thit of in sad gear me I'lly intem.
#
# for stean the to ruck? a ol peren b
# ----
# iter 31300, loss: 51.044895
# ----
#   shile,-en dent:
# Shitholo:
# I came deser,
# An wosh:
# As the ry the to hayerce danted a cormerest chardo, thou youer
# Therer
# Sor to wheriene.
# Brow?
# I pore.
#
# APtO IV:
# And chenit.
#
# AOThO:
# Ond and I so upole
# ----
# iter 31400, loss: 51.103465
# ----
#  mo homd;
# Yo damood yor sall beensed.
#
# The tANGWION:
# But and wherind hereas my
# I'll ame, thon manes prake,
# When o'd,
# on, si,
# Of if the son, a tilld, whaw gadarsers,
# Yeelr.
# Your no her
# Ovould
# Row his, s
# ----
# iter 31500, loss: 51.005077
# ----
#  use lael shatt to were.
#
# COLIXENES:
# And suthers of notmien;
# Nop pir tear speth therest,
# O usen the meathy havy forfired
# To ofecs
# Thouest coimen,
# Strips pay, wher's for faie
# Thines. wincus ind I on
# thi
# ----
# iter 31600, loss: 50.845294
# ----
#  e sty! lowe; bus, the awfir our, rest ant thon blond.
#
# CXOLOLABA:
# Un;
# You them,
# Will you on mollit: Cod soulked the and come shee! that wis chars youry no cocher,
# 't dame fike
# onllale honly castn it b
# ----
# iter 31700, loss: 51.097284
# ----
#  US:
# Lears mirk
# I'd wong:
# To sepe's Witts all wire.
#
# HERCBES:
# Few wom that rushy
# dast and prale ich sse.
#
# PrOLANUS:
# Wear hold'd not af's to mave perag,
# The's sanltngy grothrit, toors, sos yousiite:
# Dot
# ----
# iter 31800, loss: 51.083242
# ----
#  d.
#
# IOLII:
# Nant:
# Whe lo'th a forepcanstgingot onpoll's, hando.
#
# DARGulTh:
# What his to sichs ake and to shard to and thon he blosted bee and dserss fancoceassep inten yours.
#
# OXlESTAUL:
# Noacht pof
# fat
# ----
# iter 31900, loss: 50.893212
# ----
#  hord manban, your frows
# Do In whem blo'd her
# My bony heakn?
# So hangst he on he for fitone it has
# Est and's hearind prees. Seen yous with my have roung,
# My
# Sund, ap cas mord?
# In yies as homenly shane o
# ----
# iter 32000, loss: 50.688416
# ----
#  hap and sharchaly
# And to me.
#
# San mile pow ing.
#
# POLYOLICS:
# The forde lere wencooured yoe couldst: I her pofolboy; nooth a rainigon-mer of Ownow your
# On'd the mr For eagtlenng, uf him,
# And thes? hove
# ----
# iter 32100, loss: 50.513936
# ----
#  I fallio, motto'f the of muder:
# Sher,
# Hy kithmes ois not urnfer:
# Wirth on 'oopicn a, inder,
# Ans,
# Is inforesove;
# Yor tloo eacoot grown affak! thy muer day wen gaprest's if eake
# Bekt of farporave of tha
# ----
# iter 32200, loss: 50.427197
# ----
#  heen
# Theret juthe.
# Th Ielir thy
# I mofuot
# Unow lideme, frey
# The for samping rean thus hes youbllo;
# That the,
# Hisce bo; you havings shere my cole him that all mood, a mave plood buicave thow knom you ou
# ----
# iter 32300, loss: 50.036014
# ----
#  renthunt ik bety as prand, you scoun, combaish sur thesed. I thimpance ofore of mathouted my colk, uppart;
#
# Pttim:
# O mant, wottrow sformand: antervionds whaty I 'Ting; his slemas manter-of yoe and foc
# ----
# iter 32400, loss: 50.133943
# ----
#  my: as porke.
#
# ittnee trow chear balame frim and have no he: you reit, it ardinco, mire, fith: as stame hafm ware in port t
# Turthute, wer tallets Cack, an;
# Caf the cam co you knan hwouss thou, there t
# ----
# iter 32500, loss: 49.970527
# ----
#  here the one a share t, ard id!
#
# Ferkn:
# You lorder fricen-el. I a'lct
# I what nokeld ay makingon ande traid.' cugree.
# I bo it pue.
#
# Crowr, nemanne
# No plaie't cond are you bewiy spraaty at sis the parr
# ----
# iter 32600, loss: 49.726361
# ----
#  our have go be an nain ol whard, wathievin, fobe we or in sath.
#
# Khe manf way,
# Qisenchan love nave make they this nomnech has I have in bo as no of me seinw is as with thres hive; follrowalk befory no
# ----
# iter 32700, loss: 49.611152
# ----
#   the bow?
#
# AUULOUL:
# I'd of rvaecy arsheped reameds ceme whith my
# Clich make wordy! mack donding ham in ol-ulatied kathe!un at teev inmandes edst galioky and tire to me
# I move Pealltod my ipfe now I fa
# ----
# iter 32800, loss: 49.469055
# ----
#  e!
# Yo fere
# I kive bring our rost she gold word a whom thesen
# there onun thet secres
# My hewtens low this usss
# Machied hesesere, op gloce hath parr dicl; ererel ond her fid hearasind vord
# what cher pork
# ----
# iter 32900, loss: 49.603441
# ----
#  ence a bouney
# Noal, thom of hence
# ing gont and alles?'
# The made-courn,.
#
# Serontef thod withell fucks arest
# Of mys
# Sa woealw sce, yow treens seave a his whee for olloud to shaer havy the she not
# Weer k
# ----
# iter 33000, loss: 49.623671
# ----
#  il wron
# of shielingintds unon you it whot ne your the firse'd's and yourund youiald af,
# For mody that hik must all in
# wo im hinkanma; your sov.
#
# SEARIZEL:
# assfer.
#
# PEONLIUL:
# Your deatim him yer gangal
# ----
# iter 33100, loss: 49.684038
# ----
#  ver stat
# I im drany
# Swoult: fly-at Beey murpar.
# My so nears wisgee, I'll courmw-Sow are and oort this to youneneap, plosniel as
# Westrous an im's sisse so ole vikh:
# Work of prowker preen crasto's brod
# ----
# iter 33200, loss: 49.541775
# ----
#  htherer: that that havell ipscunhick?
#
# MARY:
# Lhom sony
# o kwall. couldestabes
# The wrich atwint thechouf
# Thith hor all thee, my beaver
# unlmocard gooth werchme acunemory fyoom:
# Have not whingunoow.
# Wh wo
# ----
# iter 33300, loss: 49.598711
# ----
#  wath wis crowen not in that reay my frey bigers piill I badi, she the coushielens and to her the cond
# dran of hind to deane.
#
# Whis':
# To shols whe thane
# Wild as
# friend amelt,
# Tlood Geardt sreran mard s
# ----
# iter 33400, loss: 49.740251
# ----
#  nd levempbrede, of be be she ke splear bur that themton be whard dleseller.
# Noir bark: my will. woure net to your Thos me wathegn jonest, rullit zerd vonconcentlether,
# joken at not you of wente and an
# ----
# iter 33500, loss: 49.618475
# ----
#  ay scars leblen sor semse rrime. I the houk sor bithterser whillovererneeman sill his this well mad hever sabke a me sirne, I tienguetingl so cexpoower the hiigheldsy that prest.
#
# MEPRO IS,
# ITht be se
# ----
# iter 33600, loss: 49.386975
# ----
#  hind
# I allting, wouldedged who not a, ance, frear
# shoution Dobned,
# As his of your him am and sead
# the Eved forne wake
# Cwerss the pive and yourrnconce my ore le wath make the spoonld I
# an pave gell th
# ----
# iter 33700, loss: 49.290734
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5e643d9f831f> in <module>()
#      97 # sample from the model now and then
#      98     if n % 100 == 0:
# ---> 99         sample_ix = sample(hprev, inputs[0], 200)
#     100         txt = ''.join(ix_to_char[ix] for ix in sample_ix)
#     101         print '----\n %s \n----' % (txt, )
#
# <ipython-input-6-5e643d9f831f> in sample(h, seed_ix, n)
#      73
#      74     for t in xrange(n):
# ---> 75         h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
#      76         y = np.dot(Why, h) + by
#      77         p = np.exp(y) / np.sum(np.exp(y))
#
# KeyboardInterrupt:
